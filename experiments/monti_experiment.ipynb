# %%
import pandas as pd
from sklearn import datasets
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans, DBSCAN
from sklearn.metrics import silhouette_score as sil
from sklearn.metrics import calinski_harabaz_score as ch
import numpy as np

import random

import seaborn as sns
sns.set()
# %config InlineBackend.figure_format ='retina'

# %cd ..
from monti import ConsensusCluster
# Out:
# /Users/f.dobrykh/Development/Projects

# %%
def monti(L, K, H=3):
    cls = ConsensusCluster(KMeans, L, K, H)
    cls.fit(X)
    labels = cls.predict()
    return labels

def plot(X, labels):
    sns.scatterplot(X[:, 0], X[:, 1], hue=labels)

# %%
X, y = datasets.make_moons(n_samples=200, noise=0.03, shuffle=False, random_state=42)

# %%
sns.scatterplot(X[:, 0], X[:, 1])

# %%
labels = monti(2, 10)

# %%
plot(X, labels)

# %%
blobs, _ = datasets.make_blobs(200, centers=2, shuffle=False, random_state=42)

# %%
labels = monti(2, 5)

# %%
plot(blobs, labels)
